# %%
import pandas as pd
import numpy as np
import ghostPii as gp
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.9) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
surveyResults = pd.read_csv('demo_data/medical_survey.csv')
surveyResults
# Out:
#                 Name           Phone  Aches  Cough  Fatigue  Sore Throat  \
# 0     Griffin Guzman  1-313-262-6944      0      0        1            0
# 1         Gray Burks  1-627-483-8969      1      0        0            0
# 2        Burke Gibbs  1-899-772-9407      1      0        0            0
# 3     Hilel Sheppard  1-957-866-7333      0      0        1            1
# 4      Jasper Slater  1-691-353-4183      0      0        1            0
# ..               ...             ...    ...    ...      ...          ...
# 295    Minerva Sykes  1-143-977-2591      0      1        1            1
# 296      Scott Glenn  1-325-987-3047      0      0        0            1
# 297     Whoopi Mejia  1-732-950-5226      0      0        1            1
# 298  Charity Brennan  1-383-654-0965      0      0        0            0
# 299       Reed Wells  1-760-150-1927      1      0        1            0
#
#      Runny Nose  Temperature
# 0             0        102.5
# 1             0        102.2
# 2             0         97.1
# 3             0        101.1
# 4             0        101.9
# ..          ...          ...
# 295           0         98.9
# 296           0         99.8
# 297           0         97.7
# 298           0        103.1
# 299           0        100.2
#
# [300 rows x 8 columns]

# %%
# encrypt the data using doctor's token
headers = {'Authorization': 'Token 50086974f7e8fa7dd2688300b0fe41d25ea76eaa'}
doctorContext = gp.CryptoContext(headers)

perms = {"Polys":['allpolys'], "Stats":['allstats'],"LaplaceScaleParameter":0.01}

encryptedResults = gp.NormCipherFrame(doctorContext,surveyResults,keyRange=200,permLevel=perms)
encryptedResults[0:7].frame_of_ciphertext()
# Out:
#                                                      0  \
# 0    N"!+%!u#!y#!h#!>%!H%!"#!I"!V#!B#!6#!k#!J"!E#!5...
# 1    X#!q#!l#!-#!*"!J"!)%!K#!"#!w"!7"!S!!v"!Z#!x!!F...
# 2    M#!H#!##!Y#!N#!G"!2#!f#!u"!H"!Q#!M"!g!!)"!@"!u...
# 3    '%!4#!<"!o"!@#!C#!h#!>"!0#!=#!K"!@#!w"!;%!u!!R...
# 4    W"!N#!h"!6%!5#!A"!l!!F#!a#!U#!j"![#!K#!("!l!!G...
# ..                                                 ...
# 295  G"!^"!L%!;%!V#!R#!<%!W"!-"!U%!L"!9%!]"!Y"!L#!q...
# 296  ;"!e#!S"!*%!s#!!#!i"!##!y"!S"!'#!c!!["!m!!3"!3...
# 297  s#!J"!G%!T"!n#!="!w!!z#!;"!Q"!X"!>%!d!![#!c!!,...
# 298  (#!*#!!%!b#!e"!(#!B%!_!!z!!4#!r#!;#!m"!x#!j#!j...
# 299  .#!M#!%%!.%!w!!?"!8#!B#!n"!m#!D#!l"!p!!R!!N#!T...
#
#                                               1    2    3    4    5    6
# 0    N#!E#!Z#!u"!X#!E"!<"!@#!i"!g#!1#!9#!w"!W#!  A"!  S"!  Z"!  N"!  N!!
# 1    u!!3"!R#!>"!x"!Q"!+#!Y"!8#!]!!M"!Y"!s#!Y#!  y"!  8!!  "#!  0#!  R"!
# 2    B#!@"!0#!n"!*#!z!!#"!?"!Z#!Q#!W#!3#!C#!e#!  3!!  #"!  u!!  E"!  >"!
# 3    7#!&"!s#!r!!q!!F#!+"!u!!s"!!"!d!!s!!z"!L"!  1!!  ,"!  X!!  V!!  c"!
# 4    u"!Z"!R#!B"!C#!U#!@"!#"!,"!M#!f#!Q#!g#!o#!  )"!  !"!  y!!  k"!  (#!
# ..                                          ...  ...  ...  ...  ...  ...
# 295  R"!j"!<#!D#!@#!y"!t"!y!!Q"!Q#!c"!=#!0#!z!!  2!!  t!!  k!!  3!!  -!!
# 296  V"!t"!Z"!S#!E"!c!!W"!1#!K#!n!!3"!D#!Z#!1#!  w!!  i"!  '!!  I!!  '"!
# 297  z!!e!!^#!n#!4#!9"!D"!)#!D"!p"!a!!l!!V!!k!!  ?"!  o"!  `!!  h"!  C!!
# 298  :#!m"!_!!5#!C"!(#!U#!A"!M"!("!T#!*#!p#!S"!  Z"!  3#!  ,#!  6#!  c"!
# 299  J"!v!!_!!]"!-#!0#!R#!@"!H#!C#!k!!,#!K"!U"!  I"!  U!!  S!!  +"!  d"!
#
# [300 rows x 7 columns]

# %%
# now we switch over to the data analyst's token

headers = {'Authorization': 'Token e1cb3d947e61759f1340295d4402a2392f1bf629'}
analystContext = gp.CryptoContext(headers)

encryptedResults.apiContext = analystContext

# %%
# now lets add a new column to represent whether or not the temperature is high enough for a fever
hasFever = encryptedResults[7] > 100.5
encHasFever = gp.NormCipherQuant(analystContext,hasFever,fromPlain=True)
encryptedResults = encryptedResults.horiz_merge(encHasFever)
# Out:
# API time 10.325782775878906

# %%
encryptedResults[8].ciphertext()[0:10]
# Out:
# ['O-!', "'(!", 'a0!', '4(!', 'c5!', 'G0!', 's5!', "0'!", 'w)!', '8(!']

# %%
# Now let's set up our formula for significance of symptoms
coefficientDict = {'Aches':3,'Cough':2,'Fatigue':4,'Sore Throat':2,'Runny Nose':3,'Fever':7}
formulaStr = "({Aches} * A)+({Cough} * C)+({Fatigue} * Fa)+({SoreThroat} * St)+({RunnyNose} * Rn)+({Fever}* Fe)".format(
    Aches=coefficientDict['Aches'],
    Cough=coefficientDict['Cough'],
    Fatigue=coefficientDict['Fatigue'],
    SoreThroat=coefficientDict['Sore Throat'],
    RunnyNose=coefficientDict['Runny Nose'],
    Fever=coefficientDict['Fever'],
)
variables = ['A','C','Fa','St','Rn','Fe']
formulaStr
# Out:
# '(3 * A)+(2 * C)+(4 * Fa)+(2 * St)+(3 * Rn)+(7* Fe)'

# %%
cipherLists = [[encryptedResults.cipherListOfListOfList[colIndex][i][0] for colIndex in [2,3,4,5,6,8]] for i in range(encryptedResults.rows)]
indexLists = [[encryptedResults.indicesListOfListOfList[colIndex][i][0] for colIndex in [2,3,4,5,6,8]] for i in range(encryptedResults.rows)]

diagnosisScore = gp.full_polynomial_compute(analystContext,formulaStr,variables,indexLists,cipherLists,isFloat=False,paillier=False)
# Out:
# API time 3.617603063583374

# %%
# Now we can add the diagnosis score as a new column on the encrypted data
encryptedResults = encryptedResults.horiz_merge(diagnosisScore)

# %%
# We can now split the data to get a data frame of only people whose score is above a threshold
isDiagnosed = diagnosisScore > 15
diagnosedPeople = encryptedResults.vert_slice([index for index in range(encryptedResults.rows) if isDiagnosed[index]==1])
diagnosedPeople.rows
# Out:
# API time 4.74037504196167
# 23

# %%
# As you can see we can still not access the personal info
diagnosedPeople.decrypt()
# Out:
# json failure
# <!doctype html>
# <html lang="en">
# <head>
#   <title>403 Forbidden</title>
# </head>
# <body>
#   <h1>403 Forbidden</h1><p></p>
# </body>
# </html>
# None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [20], in <module>
#       1 # As you can see we can still not access the personal info
# ----> 2 diagnosedPeople.decrypt()
#
# File ~/capnion_client_org/demo_notebooks/../src/ghostPii/data_structures/norm_cipher_frame.py:337, in NormCipherFrame.decrypt(self)
#     336 def decrypt(self):
# --> 337     decryptKeyDict = {t['id']:(t['atom_key'],t['atom_key_inv']) for t in decryption_key(
#     338         self.apiContext,
#     339         json.dumps(flatten_list(flatten_list(self.indicesListOfListOfList)))
#     340     )}
#     341     decryptKey = [decryptKeyDict[i] for i in flatten_list(flatten_list(self.indicesListOfListOfList))]
#     342     i=0
#
# TypeError: 'NoneType' object is not iterable

# %%
# But we can hand it back over to the doctor for a followup
diagnosedPeople.apiContext = doctorContext
pd.DataFrame(diagnosedPeople.decrypt()).transpose().rename({0:'Name',1:'Phone Number',2:'Aches',3:'Cough',4:'Fatigue',5:'Sore Throat',6:'Runny Nose',7:'Temperature',8:'Has Fever',9:'Score'},axis=1)
# Out:
#                    Name    Phone Number Aches Cough Fatigue Sore Throat  \
# 0   Hiroko Robles        1-367-957-7622     1     0       1           1
# 1   Lucian Beard         1-743-602-6764     1     1       1           0
# 2   Kellie Mcmillan      1-635-373-0819     0     1       1           1
# 3   Randall Meyer        1-708-406-5247     1     0       0           1
# 4   Oprah Hancock        1-489-281-5030     0     1       1           1
# 5   Valentine Hatfield   1-304-324-9286     1     1       1           0
# 6   Clayton Carrillo     1-628-303-0967     0     1       1           1
# 7   Cameron Morrison     1-833-374-6688     1     0       1           0
# 8   Sarah Lambert        1-788-722-6280     0     1       1           0
# 9   Kadeem Rivera        1-608-337-6775     0     1       1           0
# 10  Colby Hoover         1-324-372-5543     0     0       1           1
# 11  Jolie Mckay          1-823-718-0262     1     1       0           1
# 12  Hu Finley            1-319-787-0209     0     1       1           0
# 13  Vance Velazquez      1-614-512-1694     0     1       1           0
# 14  Benjamin Mcmillan    1-531-417-7685     1     1       0           1
# 15  Tamara Montoya       1-902-191-4844     1     0       1           1
# 16  Martina Baldwin      1-278-183-3992     1     1       1           1
# 17  Jaime Pruitt         1-560-581-0124     1     0       1           1
# 18  Tashya Rodgers       1-500-996-2192     1     0       1           1
# 19  Blake Barber         1-164-344-4665     0     1       1           0
# 20  Unity Hogan          1-718-208-4018     1     1       0           1
# 21  Bethany Sawyer       1-232-366-0544     1     0       1           0
# 22  Minerva Sykes        1-143-977-2591     0     1       1           1
#
#    Runny Nose Temperature Has Fever Score
# 0           1        99.1         1    20
# 1           1       103.1         1    19
# 2           0       100.2         1    16
# 3           1       102.7         1    16
# 4           1        99.2         1    18
# 5           1        99.9         1    19
# 6           0       101.2         1    16
# 7           1       102.6         1    17
# 8           1        99.5         1    16
# 9           1        97.9         1    17
# 10          1        98.5         1    17
# 11          1        98.7         1    17
# 12          1        99.4         1    17
# 13          1        99.6         1    16
# 14          1        97.6         1    17
# 15          0       101.1         1    16
# 16          1        99.4         1    21
# 17          0        99.2         1    16
# 18          0       100.8         1    16
# 19          1       101.5         1    17
# 20          1       103.3         1    17
# 21          1        97.8         1    17
# 22          0        98.9         1    16
